# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %% [markdown]
# # Extract

# %%
# Import the NYC Crime dataset csv
NYC_data = pd.read_csv('nyc_crime.csv')
NYC_data
# Out:
#          Unnamed: 0  arrest_key arrest_date  \
# 0                 0   192799737  26/01/2019
# 1                 1   193260691   6/02/2019
# 2                 2   149117452   6/01/2016
# 3                 3   190049060  15/11/2018
# 4                 4    24288194  13/09/2006
# ...             ...         ...         ...
# 1048570     1048570   147681591  10/11/2015
# 1048571     1048571   147969023  21/11/2015
# 1048572     1048572   147900399  18/11/2015
# 1048573     1048573   148166637  30/11/2015
# 1048574     1048574   148495339  12/12/2015
#
#                                          pd_desc  \
# 0                                   SEXUAL ABUSE
# 1        CRIMINAL SALE OF A CONTROLLED SUBSTANCE
# 2                                         RAPE 3
# 3                                         RAPE 1
# 4                           TRESPASS 3, CRIMINAL
# ...                                          ...
# 1048570        NY STATE LAWS,UNCLASSIFIED FELONY
# ...

# %%
# Scrape the NY State crime data
url = 'https://www.disastercenter.com/crime/nycrime.htm'
NY_data = pd.read_html(url)
NY_data
# Out:
# [                                                    0    1    2    3    4   \
#  0    New York Crime Rates 1960 - 2019  (adsbygoogle...  NaN  NaN  NaN  NaN
#  1    New York Crime Rates 1960 - 2019  (adsbygoogle...  NaN  NaN  NaN  NaN
#  2    New York Crime Rates 1960 - 2019  (adsbygoogle...  NaN  NaN  NaN  NaN
#  3    (adsbygoogle = window.adsbygoogle || []).push(...  NaN  NaN  NaN  NaN
#  4    New York Population and Number of Crimes 1960 ...  NaN  NaN  NaN  NaN
#  ..                                                 ...  ...  ...  ...  ...
#  211  Since we developed the table of "New York Popu...  NaN  NaN  NaN  NaN
#  212                                                NaN  NaN  NaN  NaN  NaN
#  213                                                NaN  NaN  NaN  NaN  NaN
#  214  New York Law Enforcement Agency Uniform Crime ...  NaN  NaN  NaN  NaN
#  215  * United States * Alaska* Alabama  * Arkansas ...  NaN  NaN  NaN  NaN
#
#        5    6    7    8    9    10   11   12
# ...

# %% [markdown]
# # Transform

# %% [markdown]
# ### NYC Crime Data

# %%
# Create a dataframe of  only the required columns and sort my arrest year
NYC_table = NYC_data[['arrest_key', 'arrest_date', 'ofns_desc', 'age_group', 'perp_sex', 'perp_race', 'arrest_boro', 'arrest_precinct']]
NYC_table.sort_values('arrest_date', inplace=True)
NYC_table
# Out:
#         arrest_key arrest_date                        ofns_desc age_group  \
# 491196     9930168   1/01/2006  OTHER OFFENSES RELATED TO THEFT     25-44
# 495487     9930100   1/01/2006                          ROBBERY     18-24
# 488100     9929917   1/01/2006     ASSAULT 3 & RELATED OFFENSES     45-64
# 486839     9929886   1/01/2006                    GRAND LARCENY     25-44
# 492258     9930046   1/01/2006     ASSAULT 3 & RELATED OFFENSES     25-44
# ...            ...         ...                              ...       ...
# 151047   206220268   9/12/2019                    GRAND LARCENY     45-64
# 151060   206220256   9/12/2019          MISCELLANEOUS PENAL LAW     25-44
# 151177   206220296   9/12/2019         VEHICLE AND TRAFFIC LAWS     45-64
# 152746   206220325   9/12/2019                   FELONY ASSAULT     45-64
# 22660    206240739   9/12/2019                   FELONY ASSAULT     25-44
#
#        perp_sex       perp_race arrest_boro  arrest_precinct
# ...

# %% [markdown]
# ### NY State Crime Data

# %%
# The required table is the 4th item in the NY_data list
NY_table = pd.DataFrame(NY_data[4])
NY_table
# Out:
#       0           1       2        3         4       5         6        7   \
# 0    NaN         NaN     NaN      NaN       NaN     NaN  Forcible      NaN
# 1   Year  Population   Index  Violent  Property  Murder      Rape  Robbery
# 2   1965    18073000  554050    58802    495248     836      2320    28182
# 3   1966    18258000  609465    62561    546904     882      2439    30098
# 4   1967    18336000  692528    75124    617404     996      2665    40202
# ..   ...         ...     ...      ...       ...     ...       ...      ...
# 62  2015    19747183  392351    75126    317225     613      4414    23879
# 63  2016    19745289  379466    74285    305181     630      4569    22316
# 64  2017    19590719  364136    70746    293390     550      6297    20122
# 65  2018    19530351  350055    68512    281543     562      6577    18191
# 66  2019    19453561  336919    69764    267155     558      6583    18068
#
#             8         9         10       11
# ...

# %%
# Formattig of column headers
NY_table = NY_table[1:]               # Remove first row
new_headers = NY_table.iloc[0]        # Save the column names 
NY_table = NY_table[1:]               # Remove the names from the first row
NY_table.columns = new_headers        # Set the column headers 
NY_table.rename(columns={NY_table.columns[8]: "Assault",
                         NY_table.columns[10]: "Theft - Larceny", 
                         NY_table.columns[11]: "Theft - Vehicle" }, inplace = True)
NY_table
# Out:
# 1   Year Population   Index Violent Property Murder  Rape Robbery Assault  \
# 2   1965   18073000  554050   58802   495248    836  2320   28182   27464
# 3   1966   18258000  609465   62561   546904    882  2439   30098   29142
# 4   1967   18336000  692528   75124   617404    996  2665   40202   31261
# 5   1968   18113000  829453   98515   730938   1185  2527   59857   34946
# 6   1969   18321000  837210  105870   731340   1324  2902   64754   36890
# ..   ...        ...     ...     ...      ...    ...   ...     ...     ...
# 62  2015   19747183  392351   75126   317225    613  4414   23879   44493
# 63  2016   19745289  379466   74285   305181    630  4569   22316   45079
# 64  2017   19590719  364136   70746   293390    550  6297   20122   43777
# 65  2018   19530351  350055   68512   281543    562  6577   18191   43182
# 66  2019   19453561  336919   69764   267155    558  6583   18068   44555
#
# 1  Burglary Theft - Vehicle Theft - Vehicle
# ...

# %%
# Table has the headers repeated within the table body which need to be removed 
NY_table.head(30)
# Out:
# 1   Year  Population    Index  Violent  Property  Murder      Rape  Robbery  \
# 2   1965    18073000   554050    58802    495248     836      2320    28182
# 3   1966    18258000   609465    62561    546904     882      2439    30098
# 4   1967    18336000   692528    75124    617404     996      2665    40202
# 5   1968    18113000   829453    98515    730938    1185      2527    59857
# 6   1969    18321000   837210   105870    731340    1324      2902    64754
# 7    NaN         NaN      NaN      NaN       NaN     NaN  Forcible      NaN
# 8   Year  Population    Index  Violent  Property  Murder      Rape  Robbery
# 9   1970    18190740   904314   124613    779701    1444      2875    81149
# 10  1971    18391000   935022   145048    789974    1823      3225    97682
# 11  1972    18366000   804605   138542    666063    2026      4199    86391
# 12  1973    18265000   814349   135468    678881    2040      4852    80795
# ...

# %%
# Convert to numeric to remove the numeric values from the table
NY_table = NY_table.apply(pd.to_numeric, errors = 'coerce').dropna()
NY_table = NY_table.astype(int)
NY_table.head(30)
# Out:
# 1   Year  Population    Index  Violent  Property  Murder  Rape  Robbery  \
# 2   1965    18073000   554050    58802    495248     836  2320    28182
# 3   1966    18258000   609465    62561    546904     882  2439    30098
# 4   1967    18336000   692528    75124    617404     996  2665    40202
# 5   1968    18113000   829453    98515    730938    1185  2527    59857
# 6   1969    18321000   837210   105870    731340    1324  2902    64754
# 9   1970    18190740   904314   124613    779701    1444  2875    81149
# 10  1971    18391000   935022   145048    789974    1823  3225    97682
# 11  1972    18366000   804605   138542    666063    2026  4199    86391
# 12  1973    18265000   814349   135468    678881    2040  4852    80795
# 13  1974    18111000   911703   145427    766276    1919  5240    86814
# 14  1975    18120000  1021197   155187    866010    1996  5099    93499
# 15  1976    18084000  1125739   156988    968751    1969  4663    95718
# ...

# %%
# Keep just the 2006-2019 date (same as NYC data)
NY_table = NY_table[NY_table['Year'] >= 2006]

# Reformat the table index
NY_table = NY_table.rename_axis(None, axis=1)
NY_table = NY_table.reset_index()
NY_table.drop('index', axis=1, inplace=True)
NY_table
# Out:
#     Year  Population   Index  Violent  Property  Murder  Rape  Robbery  \
# 0   2006    19306183  482270    83966    396304     921  3169    34489
# 1   2007    19297729  461731    79915    381816     801  2926    31094
# 2   2008    19467789  466131    77546    388585     836  2799    31789
# 3   2009    19541453  452647    75110    377537     781  2582    28141
# 4   2010    19395206  456202    76492    379710     868  2797    28630
# 5   2011    19501616  449300    77463    371837     769  2751    28405
# 6   2012    19576125  454803    79535    375268     683  2837    28633
# 7   2013    19695680  436166    77563    358603     644  2575    27241
# 8   2014    19748858  415085    75972    339113     616  4316    24036
# 9   2015    19747183  392351    75126    317225     613  4414    23879
# 10  2016    19745289  379466    74285    305181     630  4569    22316
# 11  2017    19590719  364136    70746    293390     550  6297    20122
# ...

# %% [markdown]
# # Load
